# %%
# !pip install anomalib
# !pip install lightning kornia torchmetrics torch FrEIA python-dotenv open-clip-torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 13.4 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 31.5 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=6279d7917784622b650b8ec1c5772b3026dc8e2a26fa5914a5260878f4224166
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 14.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install einops
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.4 MB/s eta 0:00:00

# %%
from anomalib.data import MVTec
from anomalib.engine import Engine
from anomalib.models import EfficientAd


dataset_root = "/kaggle/input/mvtec-ad"


dataset_categories = ["tile", "leather", "grid"]


datasets = {category: MVTec(category=category, train_batch_size=1) for category in dataset_categories}

# %%
datasets
# Out:
# {'tile': <anomalib.data.image.mvtec.MVTec at 0x7c3cc9a35960>,
#  'leather': <anomalib.data.image.mvtec.MVTec at 0x7c3cc9a351b0>,
#  'grid': <anomalib.data.image.mvtec.MVTec at 0x7c3cc85ac5b0>}

# %%
modelad = EfficientAd()
enginead = Engine(max_epochs=4)


for category, dataset in datasets.items():
    print(f"Training model for category: {category}")
    enginead.fit(datamodule=dataset, model=modelad)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# INFO:
#   | Name                  | Type                     | Params | Mode
# ...

# %%
predictions = engine.predict(
    datamodule=datamodule,
    model=model
)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
# !pip install lightning

# %%
test_results = enginead.test(
        model=modelad,
       datamodule=dataset,
        #ckpt_path=enginead.trainer.checkpoint_callback.best_model_path,
)
torch.save(modelad.state_dictx(), 'modelad.ckpt')
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.7677527666091919     │
# │       image_F1Score       │    0.8444444537162781     │
# │        pixel_AUROC        │    0.43206191062927246    │
# │       pixel_F1Score       │    0.01632615551352501    │
# └───────────────────────────┴───────────────────────────┘
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 7
#       1 test_results = enginead.test(
#       2         model=modelad,
#       3        datamodule=dataset,
#       4         #ckpt_path=enginead.trainer.checkpoint_callback.best_model_path,
# ...

# %%
from anomalib.models import Patchcore
modelpatch = Patchcore()
enginepatch = Engine(max_epochs=4)


for category, dataset in datasets.items():
    print(f"Training model for category: {category}")
    enginepatch.fit(datamodule=dataset, model=modelpatch)
# Out:
# model.safetensors:   0%|          | 0.00/276M [00:00<?, ?B/s]
# INFO: GPU available: True (cuda), used: True
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /opt/conda/lib/python3.10/site-packages/lightning/pytorch/core/optimizer.py:182: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | PatchcoreModel           | 24.9 M | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# ...

# %%
test_results = enginepatch.test(
        model=modelpatch,
       datamodule=dataset,
       
)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │            0.5            │
# │       image_F1Score       │    0.8444444537162781     │
# │        pixel_AUROC        │    0.24052836000919342    │
# │       pixel_F1Score       │   0.013713177293539047    │
# └───────────────────────────┴───────────────────────────┘

# %%
# !pip install qdrant-client

# %%
from qdrant_client.models import VectorParams
from qdrant_client import QdrantClient



client = QdrantClient(
    url="https://ca68b29b-51b7-4a92-b389-869aff3264ff.us-east4-0.gcp.cloud.qdrant.io",  
    api_key="LjBKlYl96JoX4IF948HSDNa-1jIUGwlsL-3z8A1g3x-Y1Vck2tGlYg"  
)

collection_name = "images_qdrant1"
client.recreate_collection(
    collection_name=collection_name,
    vectors_config={
        "vector_name": VectorParams(size=256, distance="Cosine")  
    }
)
# Out:
# /tmp/ipykernel_30/389492042.py:12: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# True

# %%
import torch.nn.functional as F

def extract_features(model, image):
    """Extract features from an image using the model."""
    model.eval()
    with torch.no_grad():
        
        output = model(image)

        
        features = output['anomaly_map']  
        print(f"Raw feature shape: {features.shape}")  

        
        pooled_features = F.adaptive_avg_pool2d(features, (16, 16))  
        flattened_features = pooled_features.view(features.size(0), -1)  
        print(f"Flattened feature shape: {flattened_features.shape}")  

    return flattened_features

# %%
from qdrant_client.models import PointStruct
uploaded_image_ids = []  

def upload_anomalous_features_to_qdrant(dataset, model, client, collection_name):
    model.eval()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    with torch.no_grad():
        for idx, batch in enumerate(dataset.test_dataloader()):
            images = batch["image"].to(device)
            labels = batch["label"]  

           
            features = extract_features(model, images)

            for i, feature in enumerate(features):
                 if labels[i] == 1: 
                    point_id = idx * len(images) + i  
                    try:
                        
                        client.upsert(
                            collection_name=collection_name,
                            points=[
                                PointStruct(
                                    id=point_id,  
                                    vector={"vector_name": feature.cpu().flatten().tolist()}  
                                )
                            ]
                        )
                        uploaded_image_ids.append(point_id)  
                        print(f"Uploaded point ID: {point_id}")
                    except Exception as e:
                        print(f"Error uploading point ID: {point_id}, error: {str(e)}")


upload_anomalous_features_to_qdrant(dataset, modelad, client, collection_name)
# Out:
# Raw feature shape: torch.Size([32, 1, 256, 256])
# Flattened feature shape: torch.Size([32, 256])
# Uploaded point ID: 0
# Uploaded point ID: 1
# Uploaded point ID: 2
# Uploaded point ID: 3
# Uploaded point ID: 4
# Uploaded point ID: 5
# Uploaded point ID: 6
# Uploaded point ID: 7
# Uploaded point ID: 8
# Uploaded point ID: 9
# Uploaded point ID: 10
# Uploaded point ID: 11
# Uploaded point ID: 12
# Uploaded point ID: 13
# Uploaded point ID: 14
# Uploaded point ID: 15
# Uploaded point ID: 16
# Uploaded point ID: 17
# Uploaded point ID: 18
# Uploaded point ID: 19
# Uploaded point ID: 20
# Uploaded point ID: 21
# Uploaded point ID: 22
# Uploaded point ID: 23
# Uploaded point ID: 24
# Uploaded point ID: 25
# Uploaded point ID: 26
# Uploaded point ID: 27
# Uploaded point ID: 28
# Uploaded point ID: 29
# Uploaded point ID: 30
# Uploaded point ID: 31
# Raw feature shape: torch.Size([32, 1, 256, 256])
# Flattened feature shape: torch.Size([32, 256])
# Uploaded point ID: 32
# ...

# %%
def find_similar_images(query_image, model, client, collection_name, limit=5):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    query_image = query_image.to(device)

    query_features = extract_features(model, query_image)

    query_vector = query_features.cpu().flatten().tolist()  
    print(f"Query vector shape: {len(query_vector)}")  

    
    results = client.search(
        collection_name=collection_name,
        query_vector={"name": "vector_name", "vector": query_vector},  
        limit=limit  
    )

    return results

# %%
query_image = next(iter(dataset.test_dataloader()))["image"][5]  
similar_images = find_similar_images(query_image, modelad,client, collection_name)


for result in similar_images:
    print(f"Similar Image ID: {result.id}")
    print(f"Similarity Score: {result.score}")
# Out:
# Raw feature shape: torch.Size([1, 1, 256, 256])
# Flattened feature shape: torch.Size([1, 256])
# Query vector shape: 256
# Similar Image ID: 5
# Similarity Score: 1.0
# Similar Image ID: 81
# Similarity Score: 0.9596298
# Similar Image ID: 40
# Similarity Score: 0.95725536
# Similar Image ID: 54
# Similarity Score: 0.95697117
# Similar Image ID: 55
# Similarity Score: 0.95507956

# %%
import matplotlib.pyplot as plt

# %%
plt.clf()

# %%
# %matplotlib inline

# %%
def show_similar_images(similar_images, dataset, n_images=5):
    fig, axs = plt.subplots(1, min(n_images, len(similar_images)), figsize=(15, 5))

    for i, result in enumerate(similar_images[:n_images]):  
        image_id = int(result.id)  

        
        for idx, batch in enumerate(dataset.test_dataloader()):
            if idx == image_id // len(batch["image"]): 
                image_idx_in_batch = image_id % len(batch["image"])
                similar_image = batch["image"][image_idx_in_batch]
                axs[i].imshow(similar_image.permute(1, 2, 0).cpu().numpy())  
                axs[i].set_title(f"Score: {result.score:.4f}")
                axs[i].axis('off')
                break  

    plt.show()


show_similar_images(similar_images, dataset, n_images=5)
